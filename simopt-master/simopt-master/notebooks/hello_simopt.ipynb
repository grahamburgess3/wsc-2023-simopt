# %%
import os
os.chdir('../')  # Move one level up to import simopt

# Import experiment_base module, which contains functions for experimentation.
import simopt.experiment_base

# %%
# Run 10 macroreplications of ASTRO-DF on the continuous newsvendor problem.
myexperiment = simopt.experiment_base.ProblemSolver("ASTRODF", "CNTNEWS-1")
myexperiment.run(n_macroreps=10)

# Post-process the results.
myexperiment.post_replicate(n_postreps=200)
simopt.experiment_base.post_normalize(experiments=[myexperiment], n_postreps_init_opt=200)

# Record the results and plot the mean progress curve.
myexperiment.log_experiment_results()
simopt.experiment_base.plot_progress_curves(experiments=[myexperiment], plot_type="mean", normalize=False)
# Out:
# Running macroreplication 1 of 10 of Solver ASTRODF on Problem CNTNEWS-1.
# Running macroreplication 2 of 10 of Solver ASTRODF on Problem CNTNEWS-1.
# Running macroreplication 3 of 10 of Solver ASTRODF on Problem CNTNEWS-1.
# Running macroreplication 4 of 10 of Solver ASTRODF on Problem CNTNEWS-1.
# Running macroreplication 5 of 10 of Solver ASTRODF on Problem CNTNEWS-1.
# Running macroreplication 6 of 10 of Solver ASTRODF on Problem CNTNEWS-1.
# Running macroreplication 7 of 10 of Solver ASTRODF on Problem CNTNEWS-1.
# Running macroreplication 8 of 10 of Solver ASTRODF on Problem CNTNEWS-1.
# Running macroreplication 9 of 10 of Solver ASTRODF on Problem CNTNEWS-1.
# Running macroreplication 10 of 10 of Solver ASTRODF on Problem CNTNEWS-1.
# Postreplicating macroreplication 1 of 10 of Solver ASTRODF on Problem CNTNEWS-1.
# Postreplicating macroreplication 2 of 10 of Solver ASTRODF on Problem CNTNEWS-1.
# Postreplicating macroreplication 3 of 10 of Solver ASTRODF on Problem CNTNEWS-1.
# Postreplicating macroreplication 4 of 10 of Solver ASTRODF on Problem CNTNEWS-1.
# Postreplicating macroreplication 5 of 10 of Solver ASTRODF on Problem CNTNEWS-1.
# Postreplicating macroreplication 6 of 10 of Solver ASTRODF on Problem CNTNEWS-1.
# Postreplicating macroreplication 7 of 10 of Solver ASTRODF on Problem CNTNEWS-1.
# Postreplicating macroreplication 8 of 10 of Solver ASTRODF on Problem CNTNEWS-1.
# Postreplicating macroreplication 9 of 10 of Solver ASTRODF on Problem CNTNEWS-1.
# Postreplicating macroreplication 10 of 10 of Solver ASTRODF on Problem CNTNEWS-1.
# Postnormalizing on Problem CNTNEWS-1.
# Finding f(x*)...
# 	...using best postreplicated solution as proxy for x*.
# ['experiments/plots/SOLVER_SET_on_CNTNEWS-1_mean_prog_curve_unnorm.png']

# %%
# !python -m simopt.GUI
# Out:
# No experiment file exists for ADAM on CNTNEWS-1. Creating new experiment.
# Running 10 macro-replications of RNDSRCH on CNTNEWS-1.
# Running macroreplication 1 of 10 of Solver RNDSRCH on Problem CNTNEWS-1.
# Running macroreplication 2 of 10 of Solver RNDSRCH on Problem CNTNEWS-1.
# Running macroreplication 3 of 10 of Solver RNDSRCH on Problem CNTNEWS-1.
# Running macroreplication 4 of 10 of Solver RNDSRCH on Problem CNTNEWS-1.
# Running macroreplication 5 of 10 of Solver RNDSRCH on Problem CNTNEWS-1.
# Running macroreplication 6 of 10 of Solver RNDSRCH on Problem CNTNEWS-1.
# Running macroreplication 7 of 10 of Solver RNDSRCH on Problem CNTNEWS-1.
# Running macroreplication 8 of 10 of Solver RNDSRCH on Problem CNTNEWS-1.
# Running macroreplication 9 of 10 of Solver RNDSRCH on Problem CNTNEWS-1.
# Running macroreplication 10 of 10 of Solver RNDSRCH on Problem CNTNEWS-1.
# Running 10 macro-replications of ADAM on CNTNEWS-1.
# Running macroreplication 1 of 10 of Solver ADAM on Problem CNTNEWS-1.
# Running macroreplication 2 of 10 of Solver ADAM on Problem CNTNEWS-1.
# Running macroreplication 3 of 10 of Solver ADAM on Problem CNTNEWS-1.
# Running macroreplication 4 of 10 of Solver ADAM on Problem CNTNEWS-1.
# Running macroreplication 5 of 10 of Solver ADAM on Problem CNTNEWS-1.
# Running macroreplication 6 of 10 of Solver ADAM on Problem CNTNEWS-1.
# Running macroreplication 7 of 10 of Solver ADAM on Problem CNTNEWS-1.
# Running macroreplication 8 of 10 of Solver ADAM on Problem CNTNEWS-1.
# Running macroreplication 9 of 10 of Solver ADAM on Problem CNTNEWS-1.
# Running macroreplication 10 of 10 of Solver ADAM on Problem CNTNEWS-1.
# Post-processing RNDSRCH on CNTNEWS-1.
# Postreplicating macroreplication 1 of 10 of Solver RNDSRCH on Problem CNTNEWS-1.
# Postreplicating macroreplication 2 of 10 of Solver RNDSRCH on Problem CNTNEWS-1.
# Postreplicating macroreplication 3 of 10 of Solver RNDSRCH on Problem CNTNEWS-1.
# Postreplicating macroreplication 4 of 10 of Solver RNDSRCH on Problem CNTNEWS-1.
# Postreplicating macroreplication 5 of 10 of Solver RNDSRCH on Problem CNTNEWS-1.
# Postreplicating macroreplication 6 of 10 of Solver RNDSRCH on Problem CNTNEWS-1.
# Postreplicating macroreplication 7 of 10 of Solver RNDSRCH on Problem CNTNEWS-1.
# Postreplicating macroreplication 8 of 10 of Solver RNDSRCH on Problem CNTNEWS-1.
# Postreplicating macroreplication 9 of 10 of Solver RNDSRCH on Problem CNTNEWS-1.
# Postreplicating macroreplication 10 of 10 of Solver RNDSRCH on Problem CNTNEWS-1.
# Post-processing ADAM on CNTNEWS-1.
# Postreplicating macroreplication 1 of 10 of Solver ADAM on Problem CNTNEWS-1.
# Postreplicating macroreplication 2 of 10 of Solver ADAM on Problem CNTNEWS-1.
# Postreplicating macroreplication 3 of 10 of Solver ADAM on Problem CNTNEWS-1.
# Postreplicating macroreplication 4 of 10 of Solver ADAM on Problem CNTNEWS-1.
# Postreplicating macroreplication 5 of 10 of Solver ADAM on Problem CNTNEWS-1.
# Postreplicating macroreplication 6 of 10 of Solver ADAM on Problem CNTNEWS-1.
# Postreplicating macroreplication 7 of 10 of Solver ADAM on Problem CNTNEWS-1.
# Postreplicating macroreplication 8 of 10 of Solver ADAM on Problem CNTNEWS-1.
# Postreplicating macroreplication 9 of 10 of Solver ADAM on Problem CNTNEWS-1.
# Postreplicating macroreplication 10 of 10 of Solver ADAM on Problem CNTNEWS-1.
# Postnormalizing on Problem CNTNEWS-1.
# Finding f(x*)...
# 	...using coded x*.
# ^C
